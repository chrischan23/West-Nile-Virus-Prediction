# %%
#import libraries 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

from sklearn.metrics import roc_auc_score, f1_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier, KernelDensity
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.preprocessing import StandardScaler
# from xgboost import XGBClassifier
from sklearn import svm, linear_model, datasets
from sklearn.model_selection import cross_val_score
from imblearn.over_sampling import SMOTE

# %matplotlib inline
pd.options.display.max_rows = None
pd.options.display.max_columns = None

# %%
train = pd.read_csv('../dataset/train_merged.csv')

# %%
train.head()
# Out:
#    WnvPresent  WeekofYear  Sunrise  CULEX PIPIENS  Month  CULEX RESTUANS  \
# 0           0          22      421              0      5               0
# 1           0          22      421              0      5               1
# 2           0          22      421              0      5               1
# 3           0          22      421              0      5               0
# 4           0          22      421              0      5               1
#
#    DewPoint  WetBulb  Tmin  Longitude  Sunset  Tavg  Depart  Cool  FG  Heat  \
# 0        58     65.0    60 -87.800991    1917  74.0    10.0   9.0   0   0.0
# 1        58     65.0    60 -87.800991    1917  74.0    10.0   9.0   0   0.0
# 2        58     65.0    60 -87.769279    1917  74.0    10.0   9.0   0   0.0
# 3        58     65.0    60 -87.824812    1917  74.0    10.0   9.0   0   0.0
# 4        58     65.0    60 -87.824812    1917  74.0    10.0   9.0   0   0.0
#
#    year  Tmax  BR  ResultSpeed  Station  TSRA  VCTS  CULEX TERRITANS  \
# 0  2007    88   1          5.8        1     0     0                0
# 1  2007    88   1          5.8        1     0     0                0
# 2  2007    88   1          5.8        1     0     0                0
# 3  2007    88   1          5.8        1     0     0                0
# 4  2007    88   1          5.8        1     0     0                0
#
#     Latitude  AvgSpeed  HZ  RA  TS  CULEX SALINARIUS  StnPressure  \
# 0  41.954690       6.5   1   0   0                 0        29.39
# 1  41.954690       6.5   1   0   0                 0        29.39
# 2  41.994991       6.5   1   0   0                 0        29.39
# 3  41.974089       6.5   1   0   0                 0        29.39
# 4  41.974089       6.5   1   0   0                 0        29.39
#
#    CULEX PIPIENS/RESTUANS  SeaLevel  CULEX TARSALIS  PrecipTotal  ResultDir  \
# 0                       1     30.11               0          0.0         18
# 1                       0     30.11               0          0.0         18
# 2                       0     30.11               0          0.0         18
# 3                       1     30.11               0          0.0         18
# 4                       0     30.11               0          0.0         18
#
#    DZ  CULEX ERRATICUS  MIFG
# 0   0                0     0
# 1   0                0     0
# 2   0                0     0
# 3   0                0     0
# 4   0                0     0

# %% [markdown]
# ## Feature Engineering
#
# As seen in the EDA notebook, not all features are relevant in our predictive purpose. To prepare our training data for modelling, we will be selecting features that will be able to make our model more robust in predicting the West Nile Virus.
#
# To select the best features, we will perform the following:
#
# * Remove collinear features
# * Remove features that have close to 0 correlation to WnvPresent
# * Engineer new features

# %% [markdown]
# ### Drop Collinear Features
#
# * **Tavg** - We will use this feature as the main indicator of **temperature**, hence we will drop the following collinear features:
#  * Tmin
#  * Tmax
#  * Depart(Depature from normal)
#  * Heat(Heating)
#  * Cool(Cooling)
#  * Wetbulb
#
# *  **StnPressure(Average Station Pressure)** - We will use this feature as the main indicator of **pressure** from sources such as water and atmospheric.
# Hence we will drop collinear feature:
#  * SeaLevel(Average sea level pressure)
#
# * **ResultSpeed(Resultant Speed)** - We will use this feature as the main indicator of **wind** as it includes vector and magnitude.
# We will drop collinear feature:
#  * AvgSpeed

# %%
train.drop(columns = ['Tmin', 'Tmax','Depart', 'Heat', 'Cool', 'WetBulb',
                      'SeaLevel',
                      'AvgSpeed'], inplace=True)

# %%
train.head()
# Out:
#    WnvPresent  WeekofYear  Sunrise  CULEX PIPIENS  Month  CULEX RESTUANS  \
# 0           0          22      421              0      5               0
# 1           0          22      421              0      5               1
# 2           0          22      421              0      5               1
# 3           0          22      421              0      5               0
# 4           0          22      421              0      5               1
#
#    DewPoint  Longitude  Sunset  Tavg  FG  year  BR  ResultSpeed  Station  \
# 0        58 -87.800991    1917  74.0   0  2007   1          5.8        1
# 1        58 -87.800991    1917  74.0   0  2007   1          5.8        1
# 2        58 -87.769279    1917  74.0   0  2007   1          5.8        1
# 3        58 -87.824812    1917  74.0   0  2007   1          5.8        1
# 4        58 -87.824812    1917  74.0   0  2007   1          5.8        1
#
#    TSRA  VCTS  CULEX TERRITANS   Latitude  HZ  RA  TS  CULEX SALINARIUS  \
# 0     0     0                0  41.954690   1   0   0                 0
# 1     0     0                0  41.954690   1   0   0                 0
# 2     0     0                0  41.994991   1   0   0                 0
# 3     0     0                0  41.974089   1   0   0                 0
# 4     0     0                0  41.974089   1   0   0                 0
#
#    StnPressure  CULEX PIPIENS/RESTUANS  CULEX TARSALIS  PrecipTotal  \
# 0        29.39                       1               0          0.0
# 1        29.39                       0               0          0.0
# 2        29.39                       0               0          0.0
# 3        29.39                       1               0          0.0
# 4        29.39                       0               0          0.0
#
#    ResultDir  DZ  CULEX ERRATICUS  MIFG
# 0         18   0                0     0
# 1         18   0                0     0
# 2         18   0                0     0
# 3         18   0                0     0
# 4         18   0                0     0

# %% [markdown]
# ### Drop features with low correlation with WNV
#
# As per the heatmap in the EDA notebook, we will remove the remaining weather phenomna features with least correlation with West Nile Virus and are unpredictable.
# * FG
# * BR
# * TSRA
# * VCTS
# * HZ
# * RA
# * TS
# * DZ
# * MIFG

# %%
train.drop(columns = ['FG', 'BR', 'TSRA', 
                      'VCTS', 'HZ', 'RA',
                      'TS', 'DZ', 'MIFG'
                      ], inplace=True)

# %%
train.head()
# Out:
#    WnvPresent  WeekofYear  Sunrise  CULEX PIPIENS  Month  CULEX RESTUANS  \
# 0           0          22      421              0      5               0
# 1           0          22      421              0      5               1
# 2           0          22      421              0      5               1
# 3           0          22      421              0      5               0
# 4           0          22      421              0      5               1
#
#    DewPoint  Longitude  Sunset  Tavg  year  ResultSpeed  Station  \
# 0        58 -87.800991    1917  74.0  2007          5.8        1
# 1        58 -87.800991    1917  74.0  2007          5.8        1
# 2        58 -87.769279    1917  74.0  2007          5.8        1
# 3        58 -87.824812    1917  74.0  2007          5.8        1
# 4        58 -87.824812    1917  74.0  2007          5.8        1
#
#    CULEX TERRITANS   Latitude  CULEX SALINARIUS  StnPressure  \
# 0                0  41.954690                 0        29.39
# 1                0  41.954690                 0        29.39
# 2                0  41.994991                 0        29.39
# 3                0  41.974089                 0        29.39
# 4                0  41.974089                 0        29.39
#
#    CULEX PIPIENS/RESTUANS  CULEX TARSALIS  PrecipTotal  ResultDir  \
# 0                       1               0          0.0         18
# 1                       0               0          0.0         18
# 2                       0               0          0.0         18
# 3                       1               0          0.0         18
# 4                       0               0          0.0         18
#
#    CULEX ERRATICUS
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %% [markdown]
# ### Engineer New Features
# source: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4342965/
#
# Based on our online research, while most of the weather features in the dataset have correlation with the West Nile Virus, we have found that there is a positive correlation between **Relative Humidity** and vector population dynamics of mosquito species and morbidity(degradation in health) in humans. Hence we will include engineer this feature into our dataset.

# %% [markdown]
# Source for calculation:
# * https://www.wikihow.com/Calculate-Humidity
# * https://sciencing.com/relative-humidity-7611453.html

# %%
#convert average temperature from farenheit to degree celsius
t_avg_cel = (5/9) * (train['Tavg']-32)

#convert dewpoint from farenheit to degree celsius
dewpoint_cel = (5/9) * (train['DewPoint']-32)

#calculate saturated vapor pressure
sat_pre = 6.11*10*((7.5*t_avg_cel) / (237.3+t_avg_cel))

#calculate actual vapor pressure
act_pre = 6.11*10*((7.5*dewpoint_cel) / (237.3+dewpoint_cel))

rel_humid = (act_pre/sat_pre) * 100

train['Rela_Humidity'] = rel_humid

# %%
train.head()
# Out:
#    WnvPresent  WeekofYear  Sunrise  CULEX PIPIENS  Month  CULEX RESTUANS  \
# 0           0          22      421              0      5               0
# 1           0          22      421              0      5               1
# 2           0          22      421              0      5               1
# 3           0          22      421              0      5               0
# 4           0          22      421              0      5               1
#
#    DewPoint  Longitude  Sunset  Tavg  year  ResultSpeed  Station  \
# 0        58 -87.800991    1917  74.0  2007          5.8        1
# 1        58 -87.800991    1917  74.0  2007          5.8        1
# 2        58 -87.769279    1917  74.0  2007          5.8        1
# 3        58 -87.824812    1917  74.0  2007          5.8        1
# 4        58 -87.824812    1917  74.0  2007          5.8        1
#
#    CULEX TERRITANS   Latitude  CULEX SALINARIUS  StnPressure  \
# 0                0  41.954690                 0        29.39
# 1                0  41.954690                 0        29.39
# 2                0  41.994991                 0        29.39
# 3                0  41.974089                 0        29.39
# 4                0  41.974089                 0        29.39
#
#    CULEX PIPIENS/RESTUANS  CULEX TARSALIS  PrecipTotal  ResultDir  \
# 0                       1               0          0.0         18
# 1                       0               0          0.0         18
# 2                       0               0          0.0         18
# 3                       1               0          0.0         18
# 4                       0               0          0.0         18
#
#    CULEX ERRATICUS  Rela_Humidity
# 0                0      64.090568
# 1                0      64.090568
# 2                0      64.090568
# 3                0      64.090568
# 4                0      64.090568

# %% [markdown]
# For Sunrise and the Sunset features, we will engineer the **Daylight Hours**. As per our research, mosquitoes are generally more active at higher temperatures, which allow vectors to grow rapidly espiecially in regions like North America and Europe.
#
# Thus computing daylight hours will allow us to understand if higher temperature during the day of longer days will affect the presence of West Nile Virus.
#
# We will then drop the sunset column due to its collinearity

# %%
train['Daylight_Hours'] = (train['Sunset'] - train['Sunrise'])/100
train.drop(columns = ['Sunset'], inplace=True)
train.head()
# Out:
#    WnvPresent  WeekofYear  Sunrise  CULEX PIPIENS  Month  CULEX RESTUANS  \
# 0           0          22      421              0      5               0
# 1           0          22      421              0      5               1
# 2           0          22      421              0      5               1
# 3           0          22      421              0      5               0
# 4           0          22      421              0      5               1
#
#    DewPoint  Longitude  Tavg  year  ResultSpeed  Station  CULEX TERRITANS  \
# 0        58 -87.800991  74.0  2007          5.8        1                0
# 1        58 -87.800991  74.0  2007          5.8        1                0
# 2        58 -87.769279  74.0  2007          5.8        1                0
# 3        58 -87.824812  74.0  2007          5.8        1                0
# 4        58 -87.824812  74.0  2007          5.8        1                0
#
#     Latitude  CULEX SALINARIUS  StnPressure  CULEX PIPIENS/RESTUANS  \
# 0  41.954690                 0        29.39                       1
# 1  41.954690                 0        29.39                       0
# 2  41.994991                 0        29.39                       0
# 3  41.974089                 0        29.39                       1
# 4  41.974089                 0        29.39                       0
#
#    CULEX TARSALIS  PrecipTotal  ResultDir  CULEX ERRATICUS  Rela_Humidity  \
# 0               0          0.0         18                0      64.090568
# 1               0          0.0         18                0      64.090568
# 2               0          0.0         18                0      64.090568
# 3               0          0.0         18                0      64.090568
# 4               0          0.0         18                0      64.090568
#
#    Daylight_Hours
# 0           14.96
# 1           14.96
# 2           14.96
# 3           14.96
# 4           14.96

# %% [markdown]
# ## Feature Engineer for Test Data

# %%
test = pd.read_csv('../dataset/test_merged.csv')
test.head()
# Out:
#    WeekofYear  Sunrise  CULEX PIPIENS  Month  CULEX RESTUANS  DewPoint  \
# 0          24      416              0      6               0        56
# 1          24      416              0      6               1        56
# 2          24      416              1      6               0        56
# 3          24      416              0      6               0        56
# 4          24      416              0      6               0        56
#
#    WetBulb  Tmin  Longitude  Sunset  Tavg  Depart  Cool  FG  Heat  year  Tmax  \
# 0     64.0    61 -87.800991    1926  74.0     7.0   9.0   0   0.0  2008    86
# 1     64.0    61 -87.800991    1926  74.0     7.0   9.0   0   0.0  2008    86
# 2     64.0    61 -87.800991    1926  74.0     7.0   9.0   0   0.0  2008    86
# 3     64.0    61 -87.800991    1926  74.0     7.0   9.0   0   0.0  2008    86
# 4     64.0    61 -87.800991    1926  74.0     7.0   9.0   0   0.0  2008    86
#
#    BR  ResultSpeed  Station  TSRA  VCTS  CULEX TERRITANS  Latitude  AvgSpeed  \
# 0   0          8.9        1     0     0                0  41.95469      10.0
# 1   0          8.9        1     0     0                0  41.95469      10.0
# 2   0          8.9        1     0     0                0  41.95469      10.0
# 3   0          8.9        1     0     0                0  41.95469      10.0
# 4   0          8.9        1     0     0                1  41.95469      10.0
#
#    HZ  RA  TS  CULEX SALINARIUS  StnPressure  CULEX PIPIENS/RESTUANS  \
# 0   0   0   0                 0        29.28                       1
# 1   0   0   0                 0        29.28                       0
# 2   0   0   0                 0        29.28                       0
# 3   0   0   0                 1        29.28                       0
# 4   0   0   0                 0        29.28                       0
#
#    SeaLevel  CULEX TARSALIS  PrecipTotal  ResultDir  DZ  CULEX ERRATICUS  MIFG
# 0     29.99               0          0.0         18   0                0     0
# 1     29.99               0          0.0         18   0                0     0
# 2     29.99               0          0.0         18   0                0     0
# 3     29.99               0          0.0         18   0                0     0
# 4     29.99               0          0.0         18   0                0     0

# %%
#repeat same steps
test.drop(columns = ['Tmin', 'Tmax','Depart', 'Heat', 'Cool', 'WetBulb',
                      'SeaLevel',
                      'AvgSpeed'], inplace=True)

test.drop(columns = ['FG', 'BR', 'TSRA', 
                      'VCTS', 'HZ', 'RA',
                      'TS', 'DZ', 'MIFG'
                      ], inplace=True)

# %%
#convert average temperature from farenheit to degree celsius
t_avg_cel = (5/9) * (test['Tavg']-32)

#convert dewpoint from farenheit to degree celsius
dewpoint_cel = (5/9) * (test['DewPoint']-32)

#calculate saturated vapor pressure
sat_pre = 6.11*10*((7.5*t_avg_cel) / (237.3+t_avg_cel))

#calculate actual vapor pressure
act_pre = 6.11*10*((7.5*dewpoint_cel) / (237.3+dewpoint_cel))

rel_humid = (act_pre/sat_pre) * 100

test['Rela_Humidity'] = rel_humid

# %%
test['Daylight_Hours'] = (test['Sunset'] - test['Sunrise'])/100
test.drop(columns = ['Sunset'], inplace=True)
test.head()
# Out:
#    WeekofYear  Sunrise  CULEX PIPIENS  Month  CULEX RESTUANS  DewPoint  \
# 0          24      416              0      6               0        56
# 1          24      416              0      6               1        56
# 2          24      416              1      6               0        56
# 3          24      416              0      6               0        56
# 4          24      416              0      6               0        56
#
#    Longitude  Tavg  year  ResultSpeed  Station  CULEX TERRITANS  Latitude  \
# 0 -87.800991  74.0  2008          8.9        1                0  41.95469
# 1 -87.800991  74.0  2008          8.9        1                0  41.95469
# 2 -87.800991  74.0  2008          8.9        1                0  41.95469
# 3 -87.800991  74.0  2008          8.9        1                0  41.95469
# 4 -87.800991  74.0  2008          8.9        1                1  41.95469
#
#    CULEX SALINARIUS  StnPressure  CULEX PIPIENS/RESTUANS  CULEX TARSALIS  \
# 0                 0        29.28                       1               0
# 1                 0        29.28                       0               0
# 2                 0        29.28                       0               0
# 3                 1        29.28                       0               0
# 4                 0        29.28                       0               0
#
#    PrecipTotal  ResultDir  CULEX ERRATICUS  Rela_Humidity  Daylight_Hours
# 0          0.0         18                0      59.422796            15.1
# 1          0.0         18                0      59.422796            15.1
# 2          0.0         18                0      59.422796            15.1
# 3          0.0         18                0      59.422796            15.1
# 4          0.0         18                0      59.422796            15.1

# %%
#train will have 1 more column which is our target variable
print(train.shape)
print(test.shape)
# Out:
# (9693, 23)
# (116293, 22)

# %%
#Export clean train/test dataset
train.to_csv("../dataset/train_final.csv", index = False)
test.to_csv("../dataset/test_final.csv", index = False)

# %% [markdown]
# ## Create our features matrix (X) and target vector (y)

# %%
# To get the features for X
features = [col for col in train if col != 'WnvPresent']
features
# Out:
# ['WeekofYear',
#  'Sunrise',
#  'CULEX PIPIENS',
#  'Month',
#  'CULEX RESTUANS',
#  'DewPoint',
#  'Longitude',
#  'Tavg',
#  'year',
#  'ResultSpeed',
#  'Station',
#  'CULEX TERRITANS',
#  'Latitude',
#  'CULEX SALINARIUS',
#  'StnPressure',
#  'CULEX PIPIENS/RESTUANS',
#  'CULEX TARSALIS',
#  'PrecipTotal',
#  'ResultDir',
#  'CULEX ERRATICUS',
#  'Rela_Humidity',
#  'Daylight_Hours']

# %%
X = train[features]
y = train.WnvPresent

# %% [markdown]
# ## Baseline Score

# %%
train['WnvPresent'].value_counts(normalize=True)
# Out:
# 0    0.948107
# 1    0.051893
# Name: WnvPresent, dtype: float64

# %% [markdown]
# ## Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = y, test_size =0.25, random_state = 42)

# %%
X_train_columns = X_train.columns

# %% [markdown]
# ## Scale Features

# %%
ss = StandardScaler()
X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

# %% [markdown]
# ## Imbalanced Classes

# %%
#use smote to deal with imbalanced classes
smote = SMOTE(random_state=42)
X_train, y_train = smote.fit_sample(X_train, y_train)

# %% [markdown]
# ## Logistic Regression

# %%
lr = LogisticRegression()
pipe_params = {'solver' : ['liblinear'],
               'penalty': ['l1', 'l2'],
               'C': np.logspace(-5, 1, 50)
                }
gs = GridSearchCV(lr, param_grid=pipe_params, scoring='roc_auc', cv=5, return_train_score= True, verbose=1)
gs.fit(X_train, y_train)
print(gs.best_score_)
gs.best_params_
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# 0.7907689735439872
# [Parallel(n_jobs=1)]: Done 500 out of 500 | elapsed:   30.6s finished
# {'C': 0.4498432668969444, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
gs.score(X_train, y_train), gs.score(X_test, y_test)
# Out:
# (0.7922106249004204, 0.7925991545443243)

# %%
preds = gs.predict(X_test)

# %%
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.66      0.79      2298
#            1       0.11      0.79      0.20       126
#
#     accuracy                           0.67      2424
#    macro avg       0.55      0.73      0.50      2424
# weighted avg       0.94      0.67      0.76      2424

# %% [markdown]
# ## GradientBoosting

# %%
gbc = GradientBoostingClassifier()
pipe_params_gbc = {
                'learning_rate': [0.1,0.5,0.7],
                'max_depth': [2,3,5,6],
                'n_estimators': [700,800,900]
                }
gs_gbc = GridSearchCV(gbc, param_grid=pipe_params_gbc, scoring='roc_auc', cv=3, return_train_score= True, verbose=1)
gs_gbc.fit(X_train, y_train)
print(gs_gbc.best_score_)
gs_gbc.best_params_
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [Parallel(n_jobs=1)]: Done 108 out of 108 | elapsed: 26.9min finished
# 0.9921515675139209
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 800}

# %%
gs_gbc.score(X_train, y_train), gs_gbc.score(X_test, y_test)
# Out:
# (0.9995472704817449, 0.8571998425131584)

# %%
best_gbc = gs_gbc.best_estimator_
preds_gbc = best_gbc.predict(X_test)

# %%
print(classification_report(y_test,preds_gbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97      2298
#            1       0.35      0.29      0.32       126
#
#     accuracy                           0.93      2424
#    macro avg       0.66      0.63      0.64      2424
# weighted avg       0.93      0.93      0.93      2424

# %% [markdown]
# ## AdaBoost

# %%
ada = AdaBoostClassifier()
pipe_params_ada = {
                'learning_rate': [0.8, 0.9, 1.0],
                'n_estimators': [700, 800, 900]
                }
# gs_ada = GridSearchCV(ada, param_grid=pipe_params_ada, scoring='roc_auc', cv=5, return_train_score= True, n_jobs = -1, verbose=1)
gs_ada = GridSearchCV(ada, param_grid=pipe_params_ada, scoring='roc_auc', cv=5, return_train_score= True, verbose=1)
gs_ada.fit(X_train, y_train)
print(gs_ada.best_score_)
gs_ada.best_params_
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:  5.5min finished
# 0.9693788465887797
# {'learning_rate': 1.0, 'n_estimators': 900}

# %%
gs_ada.score(X_train, y_train), gs_ada.score(X_test, y_test)
# Out:
# (0.9744103347762628, 0.8463829831323304)

# %%
best_ada = gs_ada.best_estimator_
preds_ada = best_ada.predict(X_test)

# %%
print(classification_report(y_test, preds_ada))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.87      0.92      2298
#            1       0.20      0.58      0.30       126
#
#     accuracy                           0.86      2424
#    macro avg       0.59      0.73      0.61      2424
# weighted avg       0.93      0.86      0.89      2424

# %% [markdown]
# ## KNN

# %%
knn = KNeighborsClassifier()
params = {
    'n_neighbors': range(5,20),
    'weights':['uniform'],
     'algorithm': ['auto']
}
gs_knn = GridSearchCV(knn, param_grid = params, scoring='roc_auc', verbose=1, return_train_score=True)
gs_knn.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  75 out of  75 | elapsed:  2.7min finished
# GridSearchCV(estimator=KNeighborsClassifier(),
#              param_grid={'algorithm': ['auto'], 'n_neighbors': range(5, 20),
#                          'weights': ['uniform']},
#              return_train_score=True, scoring='roc_auc', verbose=1)

# %%
gs_knn.best_params_
# Out:
# {'algorithm': 'auto', 'n_neighbors': 5, 'weights': 'uniform'}

# %%
mtest, mtrain = gs_knn.cv_results_['mean_test_score'], gs_knn.cv_results_['mean_train_score']
plt.plot(params['n_neighbors'], mtest, label='Mean Test Score')
plt.plot(params['n_neighbors'], mtrain, label='Mean Train Score')
plt.legend(loc=(1.1, .5));

# %%
gs_knn.score(X_train, y_train), gs_knn.score(X_test, y_test)
# Out:
# (0.9891080492695696, 0.7750562946385401)

# %%
cross_val_score(knn, X_train, y_train, cv=5).mean()
# Out:
# 0.9043096527482755

# %%
cross_val_score(knn, X_test, y_test, cv=5).mean()
# Out:
# 0.9422475930817074

# %%
best_knn = gs_knn.best_estimator_
preds_knn = best_knn.predict(X_test)

# %%
print(classification_report(y_test, preds_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.88      0.92      2298
#            1       0.18      0.48      0.26       126
#
#     accuracy                           0.86      2424
#    macro avg       0.58      0.68      0.59      2424
# weighted avg       0.93      0.86      0.89      2424

# %% [markdown]
# ## Random Forest

# %%
params = {
    'min_samples_split': [3],
    'min_samples_leaf': range(5, 20, 1),
    'class_weight': ['balanced'],
    'n_estimators': [1000]
}

gs_rf = GridSearchCV(RandomForestClassifier(bootstrap=True), param_grid=params, scoring='roc_auc', verbose=1)

# %%
gs_rf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  75 out of  75 | elapsed:  9.6min finished
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'class_weight': ['balanced'],
#                          'min_samples_leaf': range(5, 20),
#                          'min_samples_split': [3], 'n_estimators': [1000]},
#              scoring='roc_auc', verbose=1)

# %%
gs_rf.score(X_train, y_train), gs_rf.score(X_test, y_test)
# Out:
# (0.9910834842958046, 0.8594896183016287)

# %%
pd.Series(gs_rf.best_estimator_.feature_importances_, index=X.columns).sort_values(ascending=False).head(10)
# Out:
# Daylight_Hours    0.116877
# WeekofYear        0.101409
# Month             0.099623
# Sunrise           0.098916
# Longitude         0.088071
# Latitude          0.085109
# year              0.064982
# Tavg              0.059931
# DewPoint          0.050441
# ResultSpeed       0.044352
# dtype: float64

# %%
gs_rf.best_params_
# Out:
# {'class_weight': 'balanced',
#  'min_samples_leaf': 5,
#  'min_samples_split': 3,
#  'n_estimators': 1000}

# %%
# rd = RandomForestClassifier(class_weight = 'balanced', min_samples_leaf = 10, min_samples_split = '3', n_estimators = 1000)

# %%
# cross_val_score(rf, X_train, y_train, cv=5).mean()

# %%
# cross_val_score(rf, X_test, y_test, cv=5).mean()

# %% [markdown]
# ## Decision Tree

# %%
params = {
    'min_samples_split' : [2, 3, 4],
    'min_samples_leaf': [3, 4, 5],
    'max_depth': range(10, 20),
    'class_weight' : ['balanced'],
    'max_features': ['auto', None],
    'random_state': [42],
}

gs_dt = GridSearchCV(DecisionTreeClassifier(), param_grid=params, scoring='roc_auc')

# %%
gs_dt.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'class_weight': ['balanced'],
#                          'max_depth': range(10, 20),
#                          'max_features': ['auto', None],
#                          'min_samples_leaf': [3, 4, 5],
#                          'min_samples_split': [2, 3, 4], 'random_state': [42]},
#              scoring='roc_auc')

# %%
gs_dt.score(X_train, y_train), gs_dt.score(X_test, y_test)
# Out:
# (0.9696245640811271, 0.8232831862074682)

# %%
gs_dt.best_params_
# Out:
# {'class_weight': 'balanced',
#  'max_depth': 16,
#  'max_features': 'auto',
#  'min_samples_leaf': 4,
#  'min_samples_split': 2,
#  'random_state': 42}

# %%
# dt =DecisionTreeClassifier(class_weight='balanced', max_depth=7, max_features='auto', min_samples_leaf=3, min_samples_split=2)

# %%
# cross_val_score(dt, X_train, y_train, cv=5).mean()

# %%
# cross_val_score(dt, X_test, y_test, cv=5).mean()

# %% [markdown]
# ## XGBoost

# %%
# xgb = XGBClassifier()
# pipe_params_xgb = {
#                 'learning_rate' : [1,3,5],
#                 'max_depth' : [10,15,20], 
#                 'n_estimators' : [60,80,100],
#                 'gamma' : [0.1, 1]
#                 }
# gs_xgb = GridSearchCV(xgb, param_grid=pipe_params_xgb, scoring='roc_auc', cv=3, return_train_score= True, n_jobs = -1, verbose=1)
# gs_xgb.fit(X_train, y_train)
# print(gs_xgb.best_score_)
# gs_xgb.best_params_

# %%
# gs_xgb.score(X_train, y_train), gs_xgb.score(X_test, y_test)

# %% [markdown]
# | Model               | Training ROC AUC Score | Testing ROC AUC Score |
# |:---------------------|:------------------------|:-----------------------|
# | Logistic Regression | 0.806                  | 0.821                 |
# | Gradient Boosting   | 0.865                  | 0.857                 |
# | XGBoost             | 0.859                  | 0.850                 |
# | AdaBoost            | 0.855                  | 0.852                 |
# | KNN                 | 0.845                  | 0.836                 |
# | Random Forest       | 0.844                  | 0.856                 |
# | Decision Tree       | 0.867                  | 0.813                 |

# %% [markdown]
# ## Top 3 models

# %% [markdown]
# #### AdaBoost
# AdaBoost generalizes the data the best and hence it is the best model for us to use.

# %%
best_ada.fit(X_train, y_train)
pred = best_ada.predict(X_test)
pred_proba = [i[1] for i in best_ada.predict_proba(X_test)]

# %% [markdown]
# ## ROC Curve

# %%
pred_df = pd.DataFrame({'true_values': y_test,
                        'pred_probs':pred_proba})
pred_df
# Out:
#       true_values  pred_probs
# 8913            0    0.499671
# 6079            0    0.498620
# 2279            0    0.500286
# 9365            1    0.500125
# 4833            0    0.499521
# 9088            0    0.500544
# 2245            0    0.500336
# 2112            0    0.499796
# 703             0    0.500018
# 7589            0    0.489859
# 5250            0    0.497815
# 7449            0    0.489442
# 9483            0    0.500422
# 8861            1    0.499735
# 709             0    0.499312
# 2044            0    0.500324
# 2650            0    0.498596
# 7311            0    0.489059
# 9132            0    0.500684
# 197             0    0.488156
# 4777            0    0.499533
# 1580            0    0.500473
# 3504            0    0.488147
# 8832            0    0.500063
# 7978            0    0.499647
# 7375            0    0.488590
# 352             0    0.488726
# 9477            0    0.500146
# 4226            0    0.498058
# 2251            0    0.499967
# 3644            0    0.488582
# 4383            0    0.498617
# 5477            0    0.488649
# 5760            0    0.489079
# 5457            0    0.488568
# 1905            0    0.500205
# 9208            0    0.500615
# 4754            0    0.499190
# 898             0    0.499018
# 5682            0    0.488711
# 8078            0    0.499559
# 7301            0    0.498974
# 8797            0    0.500073
# 9370            0    0.499781
# 3069            0    0.498857
# 5664            0    0.478513
# 1718            0    0.499613
# 2130            0    0.500025
# 125             0    0.490072
# 3347            0    0.487990
# 5441            0    0.488418
# 1606            0    0.499986
# 301             0    0.489570
# 1694            0    0.500053
# 7143            0    0.499244
# 4271            0    0.498726
# 3721            0    0.488917
# 1275            0    0.499792
# 6170            0    0.499020
# 3254            0    0.487088
# 3357            0    0.487800
# 906             0    0.499345
# 2529            0    0.498940
# 2176            1    0.500212
# 5292            0    0.498256
# 1907            0    0.500361
# 8388            0    0.499074
# 1697            1    0.500014
# 674             0    0.498007
# 4529            0    0.499473
# 5494            0    0.487998
# 2928            0    0.498803
# 215             0    0.489021
# 7835            0    0.489329
# 3591            0    0.488136
# 2545            0    0.499357
# 7185            0    0.499319
# 1387            0    0.499507
# 74              0    0.487881
# 942             0    0.499260
# 306             0    0.489738
# 6462            0    0.498967
# 2876            0    0.498701
# 5639            0    0.488547
# 8639            0    0.499760
# 8313            0    0.499475
# 1083            0    0.499523
# 3215            0    0.497544
# 9008            0    0.500552
# 105             0    0.490373
# 8188            0    0.499712
# 8685            1    0.500241
# 9199            0    0.500070
# 269             0    0.488988
# 3022            0    0.499046
# 2434            1    0.499698
# 5914            0    0.498257
# 7695            0    0.489619
# 6083            0    0.499317
# 2241            1    0.499757
# 3341            0    0.487856
# 7273            0    0.499464
plt.hist(pred_df[pred_df['true_values'] == 0]['pred_probs'],
         bins=25,
         color='b',
         alpha = 0.6,
         label='Outcome = 0')
plt.hist(pred_df[pred_df['true_values'] == 1]['pred_probs'],
         bins=25,
         color='orange',
         alpha = 0.6,
         label='Outcome = 1')

# Label axes.
plt.title('Distribution of P(Outcome = 1)', fontsize=22)
plt.ylabel('Frequency', fontsize=18)
plt.xlabel('Predicted Probability that Outcome = 1', fontsize=18)

# Create legend.
plt.legend(fontsize=20);

# %%
# Create figure.
plt.figure(figsize = (10,7))

# Create threshold values. (Dashed red line in image.)
thresholds = np.linspace(0, 1, 200)

# Define function to calculate sensitivity. (True positive rate.)
def TPR(df, true_col, pred_prob_col, threshold):
    true_positive = df[(df[true_col] == 1) & (df[pred_prob_col] >= threshold)].shape[0]
    false_negative = df[(df[true_col] == 1) & (df[pred_prob_col] < threshold)].shape[0]
    return true_positive / (true_positive + false_negative)
    

# Define function to calculate 1 - specificity. (False positive rate.)
def FPR(df, true_col, pred_prob_col, threshold):
    true_negative = df[(df[true_col] == 0) & (df[pred_prob_col] <= threshold)].shape[0]
    false_positive = df[(df[true_col] == 0) & (df[pred_prob_col] > threshold)].shape[0]
    return 1 - (true_negative / (true_negative + false_positive))
    
# Calculate sensitivity & 1-specificity for each threshold between 0 and 1.
tpr_values = [TPR(pred_df, 'true_values', 'pred_probs', prob) for prob in thresholds]
fpr_values = [FPR(pred_df, 'true_values', 'pred_probs', prob) for prob in thresholds]

# Plot ROC curve.
plt.plot(fpr_values, # False Positive Rate on X-axis
         tpr_values, # True Positive Rate on Y-axis
         label='ROC Curve')

# Plot baseline. (Perfect overlap between the two populations.)
plt.plot(np.linspace(0, 1, 200),
         np.linspace(0, 1, 200),
         label='baseline',
         linestyle='--')

# Label axes.
plt.title(f'ROC Curve with AUC = {round(roc_auc_score(pred_df["true_values"], pred_df["pred_probs"]),3)}', fontsize=22)
plt.ylabel('Sensitivity', fontsize=18)
plt.xlabel('1 - Specificity', fontsize=18)

# Create legend.
plt.legend(fontsize=16);

# %% [markdown]
# ## Feature Importance

# %%
X_train
# Out:
# array([[-1.23705905, -1.0806164 , -0.5427413 , ..., -0.01172985,
#         -0.24117678,  1.01603696],
#        [ 0.06408148, -0.277038  , -0.5427413 , ..., -0.01172985,
#         -0.55865776,  0.00924957],
#        [ 0.497795  ,  0.78716043, -0.5427413 , ..., -0.01172985,
#          1.5356137 , -0.55821242],
#        ...,
#        [ 0.497795  ,  0.80887876,  1.84249844, ..., -0.01172985,
#          1.11187024, -0.58567026],
#        [-0.15277527, -0.51593968, -0.5427413 , ..., -0.01172985,
#         -0.18046777,  0.59501678],
#        [ 0.497795  ,  0.80887876, -0.5427413 , ..., -0.01172985,
#          1.60196479, -0.58567026]])

# %%
feat_impt = pd.DataFrame({'feature': X_train_columns, 
                         'importance': best_ada.feature_importances_}).sort_values(by = 'importance', ascending=True).tail(20)

feat_impt.plot.barh('feature', 'importance', figsize = (15,15))
plt.title('Top 20 Features');
