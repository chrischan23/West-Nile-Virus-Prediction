# %% [markdown]
# # Project 4 - Fighting the West Nile Virus in Chicago
#
# <img src=".images\West_Nile_Virus_Image.jpg" alt="West Nile Virus" title="The West Nile Virus" />
#
# ## Problem Statement
# **To find the most cost-effective way of eliminating the spread of the West Nile Virus from the transmission through mosquitoes**
#
# ### Background
# The West Nile Virus has been raging through the city of Chicago. According to the CDC, the virus has been the main cause of mosquito-borne diesease in the United States and it is transmitted by the bite of an infected mosquito. With the help of the Department of Public Health, data on mosquito infestation has been made available through their surveillance and control system. The data will help in determining where the best use of resource can be allocated to with the highest efficacy.
#
# ### Contents
# 1. Problem statement
# 2. Data collection
# 3. Data cleaning and EDA
# 4. Preprocessing and modeling
# 5. Model evaluation
# 6. Conclusions and limitations
#
# ### Context and Motivation
# The team at the Disease And Treatment Agency, which is a division of Societal Cures In Epidemiology and New Creative Engineering (DATA-SCIENCE), has been called upon to put the data together, analyse and put forth our recommendations. As with initiatives for public welfare and funded by the public, the aim is to direct the deployment of pesticides to areas which can yield the best results while keeping costs low.
#
# ### Stakeholders
# | Stakeholder Type | Stakeholders                 | Objective                                                                                                                                                             |
# |:------------------|:------------------------------|:-----------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Primary          | Disease And Treatment Agency | - To eredicate the threat of mosquitoes which have cause the spread of the West Nile Virus  - Find out where the pesticides can be deployed with optimal cost-benefits |
# | Secondary        | Chicago residents            | - Updated on which areas have the highest threats and take necessary measures                                                                                         |
#
# ## Data Dictionary
# ### Train and Test.csv
# | Key                    | Description                                                                                             |
# |:------------------------|:---------------------------------------------------------------------------------------------------------|
# | Date                   | Date that the WNV test is performed                                                                     |
# | Address                | Approximate address of the location of trap. This is used to send to the GeoCoder.                      |
# | Species                | Species of mosquitos                                                                                    |
# | Block                  | Block number of address                                                                                 |
# | Street                 | Street name                                                                                             |
# | Trap                   | Id of the trap                                                                                          |
# | AddressNumberAndStreet | Approximate address returned from GeoCoder                                                              |
# | Latitude               | Latitude returned from GeoCoder                                                                         |
# | Longitude              | Longitude returned from GeoCoder                                                                        |
# | AddressAccuracy        | Accuracy returned from GeoCoder                                                                         |
# | NumMosquitos           | Number of mosquitoes caught in this trap                                                                |
# | WnvPresent             | Whether West Nile Virus was present in these mosquitos. 1 means WNV is present, and 0 means not present |
#
# ### Weather
# | Key         | Notes                                                                                       |
# |:-------------|:---------------------------------------------------------------------------------------------|
# | Station     | 1 - Automated Surface Observing System (ASOS) 2 - Automated Weather Observing System (AWOS) |
# | Tmax        | Maximum temperature Fahrenheit                                                              |
# | Tmin        | Minimum temperature Fahrenheit                                                              |
# | Tavg        | Average temperature Fahrenheit                                                              |
# | Depart      | Departure from normal                                                                       |
# | DewPoint    | Average dew point                                                                           |
# | WetBulb     | Average wet bulb                                                                            |
# | Heat        | Heating (Season begins in July)                                                             |
# | Cool        | Cooling (Season begins in January)                                                          |
# | Sunrise     | Sunrise (Calculated, not observed)                                                          |
# | Sunset      | Sunset (Calculated, not observed)                                                           |
# | CodeSum     | Weather Phenomena                                                                           |
# | Depth       | Snow / Ice (on ground) in inches                                                            |
# | Water1      | Water equivalent                                                                            |
# | SnowFall    | Snowfall (Inches and tenths)                                                                |
# | PrecipTotal | Water equivalent                                                                            |
# | StnPressure | Average station pressure                                                                    |
# | SeaLevel    | Average sea level pressue                                                                   |
# | ResultSpeed | Resultant wind spped                                                                        |
# | ResultDir   | Resultant direction                                                                         |
# | AvgSpeed    | Average speed                                                                               |
#
# ### Spray
# | Key       | Description            |
# |:-----------|:------------------------|
# | Date      | Date of spray          |
# | Time      | Time of spray          |
# | Latitude  | Latitude of the spray  |
# | Longitude | Longitude of the spray |
#
# ## Executive Summary
#
# ### Context and Motivation
# The West Nile Virus in Chicago has been spreading across the city of Chicago. The proliferation of the diesease can be halted with the certain tools at our disposal. The objective of the team is to use the data shared by the Department of Public Health to derive a plan. This plan is to deploy the spraying of pesticides to the areas which are most at risk. It is with the view that the spraying of pesticide will kill off the mosquitoes.
# Hence, it is the duty of the team to propose which areas are most in need.
#
# ### Data Science Process
#
# #### Data extraction
#
# #### Data cleaning and EDA
# - Data cleaning
# - Data visualisation
# - Hypothesis testing
# - Feature engineering
#
# #### Model selection
# - Develop baseline
# - Data preparation
# - Model evaluation
# - Model selection
#
# #### Model optimisation
# - Adjust hyperparamters
# - Revaluate models
#
# #### Model testing snd recommendations
# - Test optimised models
# - Final evaluation and conclusion
#
# #### Key findings
# - Summary of data used
# - Data cleaning
# - EDA
# - Model selection
# - Model evaluation
#
# ### Recommendations
# - Address problem statement
# - Findings and takeaways
# - Further opportunities
